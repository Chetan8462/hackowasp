# %% [markdown]
# # Info About Dataset
#
# Attribute Information:
#
# 1. ID number
# 2. Diagnosis (M = malignant, B = benign)
#
#
# 3. 3-32:
#
# Ten real-valued features are computed for each cell nucleus:
#
# 1. radius (mean of distances from center to points on the perimeter)
# 2. texture (standard deviation of gray-scale values)
# 3. perimeter
# 4. area
# 5. smoothness (local variation in radius lengths)
# 6. compactness (perimeter^2 / area - 1.0)
# 7. concavity (severity of concave portions of the contour)
# 8. concave points (number of concave portions of the contour)
# 9. symmetry
# 10. fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three
# largest values) of these features were computed for each image,
# resulting in 30 features. For instance, field 3 is Mean Radius, field
# 13 is Radius SE, field 23 is Worst Radius.

# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Load & Store the data
df = pd.read_csv('data.csv')

# Print
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# Shape
df.shape
# Out:
# (569, 33)

# %%
#Empty Values
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df = df.drop('Unnamed: 32', axis=1)

# %%
# Null or missing values 
df.isnull().values.any()
# Out:
# False

# %%
# Basic Statistics
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# People with Disease and without
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#Visualize the data
sns.countplot(x='texture_mean', hue='diagnosis', data=df, palette='colorblind', edgecolor=sns.color_palette('dark', n_colors=1))
# Out:
# <AxesSubplot:xlabel='texture_mean', ylabel='count'>

# %%
#Visualize the data
sns.countplot(x='smoothness_mean', hue='diagnosis', data=df, palette='colorblind', edgecolor=sns.color_palette('dark', n_colors=1))
# Out:
# <AxesSubplot:xlabel='smoothness_mean', ylabel='count'>

# %%
#Get Correlation
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
# Split into Feature data & target data
X = df[["radius_mean", "texture_mean", "perimeter_mean", "area_mean", "smoothness_mean", "compactness_mean", "concavity_mean", "concave points_mean", "symmetry_mean"]]
Y = df['diagnosis']

# %%
# Split again - 80% Training & 20% testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
# # Feature Scaling - Scale the values to be between 0 & 1 inclusive
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state = 1)
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=1)

# %%
# Accuracy on training data set
model = forest
model.score(X_train, Y_train)
# Out:
# 1.0

# %%
# Accuracy on test data set
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, model.predict(X_test))

TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]

# Confusion Matrix
print(cm)

# Model Accuracy
acc = (TP+TN)/(TP+TN+FN+FP)
print("Accuracy:", acc)
# Out:
# [[76  4]
#  [ 3 31]]
# Accuracy: 0.9385964912280702

# %%
model.predict(X_test)
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M'], dtype=object)

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
X_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 480        12.16         18.03           78.29      455.3          0.09087
# 91         15.37         22.76          100.20      728.2          0.09200
# 133        15.71         13.93          102.00      761.7          0.09462
# 166        10.80          9.71           68.77      357.6          0.09594
# 527        12.34         12.27           78.94      468.5          0.09003
# ..           ...           ...             ...        ...              ...
# 69         12.78         16.49           81.37      502.5          0.09831
# 306        13.20         15.82           84.07      537.3          0.08511
# 173        11.08         14.71           70.21      372.7          0.10060
# 215        13.86         16.93           90.96      578.9          0.10260
# 5          12.45         15.70           82.57      477.1          0.12780
#
# ...

# %% [markdown]
# # Example

# %%
testdata = [[12.16, 18.03, 78.29, 455.3, 0.09087, 0.07838, 0.029160, 0.015270, 0.1464]]
nptest = np.array(testdata)

# %%
x = model.predict(nptest)

# %%
print(x)
# Out:
# ['B']

# %% [markdown]
# # Export Model

# %%
import pickle
# Save the Modle to file in the current working directory

Pkl_Filename = "Breast_Cancer_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)

# %% [markdown]
# # Import & Test Model

# %%
import pickle

Pkl_Filename = "Breast_Cancer_Model.pkl"

with open(Pkl_Filename, 'rb') as file:  
    Pickled_Breast_Cancer_Model = pickle.load(file)

# %%
# Sample Data
testdata = [[12.16, 18.03, 78.29, 455.3, 0.09087, 0.07838, 0.029160, 0.015270, 0.1464]]
#Conversion
nptest = np.array(testdata)
#Prediction
x = Pickled_Breast_Cancer_Model.predict(nptest)
print(x)
# Out:
# ['B']

# %%
model.predict(X_train)
# Out:
# array(['M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'M',
#        'B', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B',
#        'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
# ...
